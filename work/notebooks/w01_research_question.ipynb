# %% [markdown]
# <a href="https://colab.research.google.com/github/SohaibWaheed21/Flyrank-ML-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FlyRank-Internship/week1-flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *I chose **Lane 3: Structured Content Archetype Clustering**. I chose this lane because I want to discover whether pages naturally form different performance groups based on their metrics. Instead of looking at individual pages one by one, grouping similar pages can help identify common patterns and support decisions such as which pages to protect, improve, monitor, or review further.*

# %%
# !git clone https://github.com/FlyRank-Internship/week1-flyrank-ml-internship-starter.git
# Out:
# Cloning into 'week1-flyrank-ml-internship-starter'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 203 (delta 92), reused 92 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (203/203), 1.96 MiB | 10.32 MiB/s, done.
# Resolving deltas: 100% (92/92), done.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ## Research Question
#
# Can webpages be grouped into meaningful performance archetypes based on content and search metrics, enabling content teams to make more informed decisions about how to manage different types of pages?
#
# ### Decision
# This project helps content or SEO teams decide how different groups of webpages should be managed.
#
# ### Action
# Based on the identified archetype, the team can decide whether to protect, improve, refresh, monitor, or consider pruning a page.
#
# ### Cost of a Wrong Recommendation
# If pages are grouped incorrectly, the team may spend time improving pages that do not need attention or overlook pages that could benefit from optimization. This can waste resources and miss valuable opportunities.
#
# ### Why Data/ML Helps
# The dataset contains many different content and search metrics. Clustering can analyze these metrics together and identify meaningful groups of similar pages that would be difficult to define using a single manual rule.

# %%
import os

os.chdir("week1-flyrank-ml-internship-starter")
print(os.getcwd())
# Out:
# /content/week1-flyrank-ml-internship-starter

# %%
import os

print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# True

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *The starter dataset contains 30,000 webpages, providing a large sample for identifying different performance archetypes. It includes three content types, with keyword articles being the largest group (27,207 pages), followed by Feedly articles (2,096) and comparison articles (697). The pages also show different performance trends: 16,262 are declining, 5,962 are stable, 4,388 are improving, 2,236 are new, and 1,152 are flat. These differences suggest that the dataset contains a variety of page behaviors, making it suitable for exploring meaningful content archetypes rather than treating every page the same.*

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# 1. Total pages
print("Total pages:", len(df))

# 2. Different content types
print("\nContent types:")
print(df["content_type"].value_counts())

# 3. Trend direction distribution
print("\nTrend direction:")
print(df["trend_direction"].value_counts())
# Out:
# Total pages: 30000
#
# Content types:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64
#
# Trend direction:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *This project can identify groups of webpages with similar characteristics based on the available content and search metrics. These clusters are intended to support decision-making by helping content teams understand common performance patterns and prioritize appropriate actions. The findings will be observational and directional rather than causal.*
#
# *This project cannot prove why a page performs well or poorly, predict changes in Google's algorithm, or claim that belonging to a particular cluster guarantees a specific outcome. The identified archetypes should be treated as a decision-support tool, not as definitive labels.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
